# %% [markdown]
# # Get data via SQLAlchemy

# %%
import sqlalchemy, pickle
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String
from sqlalchemy.orm import sessionmaker
from sqlalchemy import and_, or_
import MySQLdb, pickle

# %% [markdown]
# ### Access to MySQL Server

# %%
pw = pickle.load(open("../crawler/mysql_pw.pickle", "rb"))

# %%
engine = sqlalchemy.create_engine("mysql+mysqldb://root:" + pw + "@52.78.44.120/project_rookie")

# %% [markdown]
# ### ORM

# %%
Base = declarative_base()
class Debut(Base):
    __tablename__ = 'debut_album'

    index = Column(Integer, primary_key=True)
    artist = Column(String)
    album = Column(String)
    genre = Column(String)
    single_count = Column(Integer)
    
    def __init__(self, index, artist, album, genre, single_count):
        self.index = index
        self.artist = artist
        self.album = album
        self.genre = genre
        self.single_count = single_count
    
    def __repr__(self):
        return "<index {}, {}, {}, {}, {}>".format(self.index, self.artist, self.album, self.genre, self.single_count)

# %%
Base.metadata.create_all(engine)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
def disp(datas):
    for data in datas:
        print(data)

# %%
results = session.query(Debut).all()
results[0].__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x111d925c0>,
#  'album': '2Cellos',
#  'artist': '2Cellos',
#  'genre': 'Cello rock, classical crossover',
#  'index': 0,
#  'single_count': 3}

# %% [markdown]
# ### Convert data into dataframe

# %%
def orm_to_df(orm):

    df = pd.DataFrame(columns=['artist', 'album', 'genre', 'single_count'])

    for i in orm:

        data = {
            'artist' : i.__dict__['artist'],
            'album' : i.__dict__['album'],
            'genre' : i.__dict__['genre'],
            'single_count' : i.__dict__['single_count'],
        }
        df.loc[len(df)] = data
        
    return df

# %% [markdown]
# ### Regroup genres into `hiphop`, `rnb`, `soul`, `funk`, `pop`

# %%
import pandas as pd

# %%
hiphop = session.query(Debut).filter(and_(~Debut.genre.contains(['K-pop']), Debut.genre.contains(["hop"])))
hiphop_df = orm_to_df(hiphop)
print(hiphop_df.shape)
hiphop_df.head()
# Out:
# (294, 4)
#                artist            album  \
# 0  Flash Bang Grenada        10 Haters
# 1        Aggro Santos  AggroSantos.com
# 2                 AKA        Altar Ego
# 3             Shlohmo        Bad Vibes
# 4      Glasses Malone    Beach Cruiser
#
#                                       genre single_count
# 0                       Alternative hip hop            0
# 1                            Hip hop, dance            3
# 2  Hip hop, Rap, English, Setswana, isiZulu            4
# 3          Electronic, instrumental hip hop            0
# 4           Gangsta rap, West Coast hip hop            4

# %%
rap = session.query(Debut).filter(and_(~Debut.genre.contains(['K-pop']), Debut.genre.contains(["Rap"])))
rap_df = orm_to_df(rap)
print(rap_df.shape)
rap_df.head()
# Out:
# (80, 4)
#            artist             album  \
# 0             AKA         Altar Ego
# 1  Glasses Malone     Beach Cruiser
# 2     Cities Aviv      Digital Lows
# 3  B.G. Knocc Out  Eazy-E's Protege
# 4        Jay Rock    Follow Me Home
#
#                                                genre single_count
# 0           Hip hop, Rap, English, Setswana, isiZulu            4
# 1                    Gangsta rap, West Coast hip hop            4
# 2  Alternative hip hop, cloud rap, experimental h...            0
# 3            G-funk, West Coast hip hop, Gangsta rap            1
# 4                    West coast hip hop, gangsta rap            2

# %%
trap = session.query(Debut).filter(and_(~Debut.genre.contains(['K-pop']), Debut.genre.contains(["trap"])))
trap_df = orm_to_df(trap)
print(trap_df.shape)
trap_df.head()
# Out:
# (29, 4)
#            artist                     album  \
# 0            Joke                   Ateyaba
# 1  Dillon Francis  Money Sucks Friends Rule
# 2           Emtee                     Avery
# 3       Fetty Wap                 Fetty Wap
# 4        Lil Durk          Remember My Name
#
#                                                genre single_count
# 0  Hip hop, french rap, trap, Hardcore Rap, Dirty...            7
# 1    Electro house, EDM, synth-pop, trap, moombahton            7
# 2          Trap, English, Sesotho, Setswana, isiZulu            5
# 3                                      Hip hop, trap            4
# 4                               Hip hop, trap, drill            1

# %%
hiphop_df = pd.concat([hiphop_df, rap_df, trap_df])
hiphop_df.drop_duplicates(['artist', 'album'], inplace=True)
hiphop_df['genre'] = "hiphop"
hiphop_df
# Out:
#                 artist                              album   genre single_count
# 0   Flash Bang Grenada                          10 Haters  hiphop            0
# 1         Aggro Santos                    AggroSantos.com  hiphop            3
# 2                  AKA                          Altar Ego  hiphop            4
# 3              Shlohmo                          Bad Vibes  hiphop            0
# 4       Glasses Malone                      Beach Cruiser  hiphop            4
# 5      Shabazz Palaces                           Black Up  hiphop            0
# 6           Mac Miller                    Blue Slide Park  hiphop            4
# 7               Phonte             Charity Starts at Home  hiphop            0
# 8              J. Cole     Cole World: The Sideline Story  hiphop            3
# 9          Cities Aviv                       Digital Lows  hiphop            0
# 10             Pac Div                            The DiV  hiphop            0
# 11      B.G. Knocc Out                   Eazy-E's Protege  hiphop            1
# 12          AraabMuzik                   Electronic Dream  hiphop            0
# 13               Emika                              Emika  hiphop            5
# 14            Big Sean                     Finally Famous  hiphop            3
# 15            Jay Rock                     Follow Me Home  hiphop            2
# 16               Torae                     For the Record  hiphop            2
# 17         Dom Kennedy     From the Westside with Love II  hiphop            0
# 18                DELS                                GOB  hiphop            4
# 19              Saigon      The Greatest Story Never Told  hiphop            4
# 20        Clams Casino                      Instrumentals  hiphop            0
# 21  Cali Swag District                       The Kickback  hiphop            3
# 22             Ab-Soul                 Longterm Mentality  hiphop            0
# 23                Mann                       Mann's World  hiphop            3
# 24      David Carreira                        n. 1 (No 1)  hiphop            1
# 25   Mindless Behavior                            #1 Girl  hiphop            4
# 26        The Internet                Purple Naked Ladies  hiphop            4
# 27            Yelawolf                        Radioactive  hiphop            2
# 28           Smoke DZA                     Rolling Stoned  hiphop            0
# 29           Mr. Envi'                   Rydaz Redemption  hiphop            0
# ..                 ...                                ...     ...          ...
# 11               Glory                        Celebration  hiphop            1
# 13                Jovi      H.I.V (Humanity is Vanishing)  hiphop            0
# 14              Elokuu                     Haavaki saapuu  hiphop            0
# 15                 Cro                               Raop  hiphop           37
# 16        Daveed Diggs            Small Things to a Giant  hiphop            0
# 17              Spekti                    Diktaattorimies  hiphop            3
# 20     Tuomas Kauhanen                   Sano vaan Tuomas  hiphop            0
# 21        Colette Carr                 Skitszo Collection  hiphop           20
# 22     Something Awful                       Taking Lives  hiphop            0
# 23   Sensato del Patio    We Ain't Even Supposed 2 B Here  hiphop            6
# 26       Azealia Banks         Broke with Expensive Taste  hiphop            4
# 27                 JUL                   Dans ma paranoia  hiphop            1
# 28      Dillon Francis           Money Sucks Friends Rule  hiphop            7
# 29               Phyno                   No Guts No Glory  hiphop            4
# 31         Neon Jungle              Welcome to the Jungle  hiphop            5
# 32            Justimus                          Wunderboy  hiphop            0
# 33               Emtee                              Avery  hiphop            5
# 37            DJ Hoppa                 'Hoppa and Friends  hiphop            0
# 39            Paperi T                     Malarian pelko  hiphop            0
# 50   From Ashes to New                            Day One  hiphop            4
# 51            DJ Snake                             Encore  hiphop            4
# 53          Xu Weizhou                              Light  hiphop            5
# 55          Hacktivist                    Outside the Box  hiphop            5
# 60            Lil Peep  Come Over When You're Sober Pt. 1  hiphop            0
# 67            Powerflo                           Powerflo  hiphop            3
# 68    Prophets of Rage                   Prophets of Rage  hiphop            0
# 75        Mike Shinoda                     Post Traumatic  hiphop            2
# 76          Maxo Kream                             Punken  hiphop            0
# 77             Lil Xan                     Total Xanarchy  hiphop            4
# 79        Rich the Kid                 The World Is Yours  hiphop            3
#
# [327 rows x 4 columns]

# %%
rnb = session.query(Debut).filter(and_(~Debut.genre.contains(['K-pop']), Debut.genre.contains(["R&B"])))
rnb_df = orm_to_df(rnb)
rnb_df['genre'] = 'rnb'
print(rnb_df.shape)
rnb_df.head()
# Out:
# (197, 4)
#           artist                   album genre single_count
# 0  Alexis Jordan           Alexis Jordan   rnb            3
# 1         Phonte  Charity Starts at Home   rnb            0
# 2      Joe Jonas                Fastlife   rnb            2
# 3   Romeo Santos          Formula Vol. 1   rnb            6
# 4    Alyssa Reid                The Game   rnb            3

# %%
soul = session.query(Debut).filter(and_(~Debut.genre.contains(['K-pop']), Debut.genre.contains(["soul"])))
soul_df = orm_to_df(soul)
soul_df['genre'] = 'soul'
print(soul_df.shape)
soul_df.head()
# Out:
# (112, 4)
#                 artist                      album genre single_count
# 0         Andy Grammer               Andy Grammer  soul            3
# 1      Vintage Trouble  The Bomb Shelter Sessions  soul            3
# 2  The Horrible Crowes                      Elsie  soul            1
# 3               Jamala            For Every Heart  soul            3
# 4     Graham Alexander           Graham Alexander  soul            0

# %%
funk = session.query(Debut).filter(and_(~Debut.genre.contains(['K-pop']), Debut.genre.contains(["funk"])))
funk_df = orm_to_df(funk)
funk_df['genre'] = 'funk'
print(funk_df.shape)
funk_df.head()
# Out:
# (28, 4)
#              artist                 album genre single_count
# 0    Ford & Lopatin      Channel Pressure  funk            2
# 1    B.G. Knocc Out      Eazy-E's Protege  funk            1
# 2  Graham Alexander      Graham Alexander  funk            0
# 3     Katie Waissel         Katie Waissel  funk            0
# 4   Charles Bradley  No Time for Dreaming  funk            2

# %%
pop = session.query(Debut).filter(and_(~Debut.genre.contains(['K-pop']), Debut.genre.contains(["pop"])))
pop_df = orm_to_df(pop)
pop_df['genre'] = 'pop'
print(pop_df.shape)
pop_df.head()
# Out:
# (714, 4)
#                      artist          album genre single_count
# 0  Her Majesty & the Wolves            111   pop            3
# 1              CocknBullKid      Adulthood   pop            4
# 2                The Adults     The Adults   pop            0
# 3             Alexis Jordan  Alexis Jordan   pop            3
# 4            Amanda Fondell   All This Way   pop            1

# %% [markdown]
# ### Concat all genres and drop duplicates rows (overlapping genres)

# %%
df_list = pd.concat([hiphop_df, rap_df, trap_df, rnb_df, soul_df, funk_df, pop_df])
len(df_list)
# Out:
# 1487

# %%
df_list = df_list.drop_duplicates(['artist', 'album'])
print(df_list.shape)
df_list.head()
# Out:
# (1094, 4)
#                artist            album   genre single_count
# 0  Flash Bang Grenada        10 Haters  hiphop            0
# 1        Aggro Santos  AggroSantos.com  hiphop            3
# 2                 AKA        Altar Ego  hiphop            4
# 3             Shlohmo        Bad Vibes  hiphop            0
# 4      Glasses Malone    Beach Cruiser  hiphop            4

# %% [markdown]
# ### Save to csv file

# %%
df_list.to_csv('../data/final_list_debut_album.csv', index=False)
