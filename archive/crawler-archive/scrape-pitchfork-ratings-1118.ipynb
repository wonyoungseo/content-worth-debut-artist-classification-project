# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import json
from urllib.request import urlopen
from tqdm import tqdm_notebook

# %% [markdown]
# # Crawling Pitchfork Review Rating

# %%
def pf_rating(starting, ending):

    df = pd.DataFrame(columns=['artists', 'albums','genre', 'release_date', 'ratings'])

    for j in tqdm_notebook(range(starting, ending, 12)):

        url = 'https://pitchfork.com/api/v2/search/?types=reviews&hierarchy=sections%2Freviews%2Falbums&sort=publishdate%20desc%2Cposition%20asc&size=12&start=' + str(j)
        data = json.load(urlopen(url))

        for i in range(len(data['results']['list'])):

            try:
                artist_name = data['results']['list'][i]['artists'][0]['display_name']
            except IndexError:
                artist_name = "Various Artist"

            album_name = data['results']['list'][i]['tombstone']['albums'][0]['album']['display_name']
            rating_score = data['results']['list'][i]['tombstone']['albums'][0]['rating']['rating']
            release_date = data['results']['list'][i]['pubDate'][:-14]

            genre_ls = []
            for k in range(len(data['results']['list'][i]['genres'])):
                genre_k = data['results']['list'][i]['genres'][k]['display_name']
                genre_ls.append(genre_k)



            input_data={
                'artists' : artist_name,
                'albums' : album_name,
                'genre' : genre_ls,
                'release_date' : release_date,
                'ratings' : rating_score,
            }

            df.loc[len(df)] = input_data
    
    return df

# %%
df1 = pf_rating(0, 2400)

# %%
df2 = pf_rating(2401, 4800)
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
df3 = pf_rating(4801, 6000)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
df4 = pf_rating(6001, 8400)
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
df5 = pf_rating(8401, 8772)
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))

# %%
df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
df = df[:8748]

# %%
df.shape
# Out:
# (8748, 5)

# %%
df.to_csv("../data/pitchfork_rating_1118.csv", index=False)

# %%
pd.read_csv("../data/pitchfork_rating_1118.csv")
# Out:
#                          artists                                       albums  \
# 0                   The National                     Boxer (Live in Brussels)
# 1                     Smokepurpp                               Bless Yo Trap
# 2                   Shuggie Otis                                Inter-Fusion
# 3                    Post Animal              When I Think of You in a Castle
# 4                      John Maus                                    Addendum
# 5                  Alexis Taylor                             Beautiful Thing
# 6        International Harvester                                      Remains
# 7               nothing,nowhere.                                       ruiner
# 8                 Various Artist   BC35: The 35 Year Anniversary of BC Studio
# 9                        Tinashe                                     Joyride
# 10                Robert Glasper                    The ArtScience Remixes EP
# 11               Littlebabyangel                                         Gada
# 12                Lena Willikens                                Selectors 005
# 13                 Mouse on Mars                           Dimensional People
# 14                Princess Nokia                             A Girl Cried Red
# 15             Ross From Friends                                  Aphelion EP
# 16                  Daniel Avery                               Song for Alpha
# 17                    Neil Young              Roxy: Tonight’s the Night Live
# 18                  War On Women                             Capture the Flag
# 19                 Sarah Davachi          Let Night Come On Bells End the Day
# 20                           GUM                                 The Underdog
# 21                   Mr. Fingers                         Cerebral Hemispheres
# 22                     King Tuff                                    The Other
# 23                         µ-Ziq                         Challenge Me Foolish
# 24                   Florentino                                 Fragmentos EP
# 25                        Eminem                      The Marshall Mathers LP
# 26                Various Artist                   Johnny Cash: Forever Words
# 27              Anna & Elizabeth                    The Invisible Comes to Us
# 28                          Kwes                            Songs for Midi EP
# 29                          E-40                      Connected and Respected
# ...                          ...                                          ...
# 8718                   The Beets                                    Stay Home
# 8719              Future Islands                                 Undressed EP
# 8720                  Gatekeeper                                      Giza EP
# 8721              Tapes 'n Tapes                                      Outside
# 8722                    Yeasayer                    Live at Ancienne Belgique
# 8723                Soft Landing                                 Soft Landing
# 8724           The Parting Gifts                         Strychnine Dandelion
# 8725                   Scientist  Scientist Launches Dubstep Into Outer Space
# 8726                    R. Kelly                                  Love Letter
# 8727                      M.I.A.                                  Vicki Leekx
# 8728            The Phantom Band                                    The Wants
# 8729                        CFCF                                 The River EP
# 8730                    Tensnake                                 In the House
# 8731                          JJ                                        Kills
# 8732                    Gorillaz                                     The Fall
# 8733             Eternal Summers                                       Silver
# 8734             Floored By Four                              Floored By Four
# 8735                Shara Worden                                     Penelope
# 8736                Jürgen Paape                                  Kompilation
# 8737             Vampire Weekend                            iTunes Session EP
# 8738                 Sheek Louch                        Donnie G: Don Gorilla
# 8739                     Callers                                 Life of Love
# 8740                 Wooden Wand                                   Death Seat
# 8741  Ryan Adams & the Cardinals                                       III/IV
# 8742                   The Knife                                        Seeds
# 8743                 Solar Bears                          She Was Coloured In
# 8744                Big Troubles                                        Worry
# 8745               Jason Forrest                                    Utopia EP
# 8746                  Shackleton                                    Fabric 55
# 8747            Ghostface Killah                                  Apollo Kids
#
#                                        genre release_date  ratings
# 0                                   ['Rock']   2018-04-21      6.0
# 1                                    ['Rap']   2018-04-21      4.8
# 2                                   ['Rock']   2018-04-21      4.6
# 3                                   ['Rock']   2018-04-21      6.9
# 4                   ['Experimental', 'Rock']   2018-04-20      7.4
# 5                             ['Electronic']   2018-04-20      6.8
# 6                                   ['Rock']   2018-04-20      8.4
# 7                                    ['Rap']   2018-04-20      5.6
# 8                                         []   2018-04-20      7.3
# 9                                ['Pop/R&B']   2018-04-19      6.8
# 10                       ['Jazz', 'Pop/R&B']   2018-04-19      6.7
# 11                               ['Pop/R&B']   2018-04-19      7.3
# 12                            ['Electronic']   2018-04-19      7.8
# 13                            ['Electronic']   2018-04-18      7.6
# 14                                   ['Rap']   2018-04-18      5.9
# 15                            ['Electronic']   2018-04-18      7.1
# 16                            ['Electronic']   2018-04-18      6.7
# 17                                  ['Rock']   2018-04-17      8.3
# 18                                  ['Rock']   2018-04-17      7.6
# 19                            ['Electronic']   2018-04-17      7.5
# 20                                  ['Rock']   2018-04-17      7.2
# 21                            ['Electronic']   2018-04-16      7.4
# 22                                  ['Rock']   2018-04-16      6.5
# 23                            ['Electronic']   2018-04-16      5.8
# 24                            ['Electronic']   2018-04-16      7.3
# 25                                   ['Rap']   2018-04-15      9.4
# 26                                        []   2018-04-14      7.0
# 27                          ['Experimental']   2018-04-14      7.2
# 28                          ['Experimental']   2018-04-14      7.5
# 29                                   ['Rap']   2018-04-14      6.7
# ...                                      ...          ...      ...
# 8718                  ['Electronic', 'Rock']   2011-01-10      7.6
# 8719                                ['Rock']   2011-01-10      7.1
# 8720                  ['Electronic', 'Rock']   2011-01-10      7.7
# 8721                ['Experimental', 'Rock']   2011-01-10      5.5
# 8722                  ['Electronic', 'Rock']   2011-01-10      7.4
# 8723                                      []   2011-01-07      6.7
# 8724                  ['Electronic', 'Rock']   2011-01-07      7.5
# 8725                              ['Global']   2011-01-07      7.7
# 8726                             ['Pop/R&B']   2011-01-07      8.2
# 8727                   ['Global', 'Pop/R&B']   2011-01-07      7.8
# 8728                                ['Rock']   2011-01-06      6.5
# 8729                          ['Electronic']   2011-01-06      6.8
# 8730                          ['Electronic']   2011-01-06      7.9
# 8731                  ['Electronic', 'Rock']   2011-01-06      7.6
# 8732                  ['Electronic', 'Rock']   2011-01-06      5.8
# 8733                                ['Rock']   2011-01-05      6.6
# 8734                                ['Rock']   2011-01-05      4.6
# 8735                ['Rock', 'Experimental']   2011-01-05      8.2
# 8736                          ['Electronic']   2011-01-05      7.9
# 8737                                ['Rock']   2011-01-05      8.0
# 8738                                 ['Rap']   2011-01-04      5.3
# 8739                ['Folk/Country', 'Rock']   2011-01-04      7.6
# 8740                                ['Rock']   2011-01-04      7.4
# 8741                                      []   2011-01-04      6.9
# 8742  ['Electronic', 'Experimental', 'Rock']   2011-01-04      7.3
# 8743                          ['Electronic']   2011-01-03      6.9
# 8744                                ['Rock']   2011-01-03      7.5
# 8745                          ['Electronic']   2011-01-03      6.5
# 8746                          ['Electronic']   2011-01-03      7.7
# 8747                                 ['Rap']   2011-01-03      7.3
#
# [8748 rows x 5 columns]
